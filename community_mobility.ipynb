# %%
import numpy as np
import pandas as pd

import seaborn as sn
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# import data
global_mobility = pd.read_csv('data/Global_Mobility_Report.csv', low_memory=False)

# %%
global_mobility.head()
# Out:
#   country_region_code        country_region sub_region_1 sub_region_2  \
# 0                  AE  United Arab Emirates          NaN          NaN
# 1                  AE  United Arab Emirates          NaN          NaN
# 2                  AE  United Arab Emirates          NaN          NaN
# 3                  AE  United Arab Emirates          NaN          NaN
# 4                  AE  United Arab Emirates          NaN          NaN
#
#          date  retail_and_recreation_percent_change_from_baseline  \
# 0  2020-02-15                                                0.0
# 1  2020-02-16                                                1.0
# 2  2020-02-17                                               -1.0
# 3  2020-02-18                                               -2.0
# 4  2020-02-19                                               -2.0
#
#    grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                4.0
# ...

# %%
canada_mobility = global_mobility.loc[global_mobility['country_region_code'] == 'CA']

# %%
canada_mobility.sub_region_1.value_counts()
# Out:
# Alberta                      101
# British Columbia             101
# Saskatchewan                 101
# Northwest Territories        101
# Ontario                      101
# Prince Edward Island         101
# Quebec                       101
# Manitoba                     101
# New Brunswick                101
# Nova Scotia                  101
# Newfoundland and Labrador    101
# Yukon                         95
# Nunavut                       88
# Name: sub_region_1, dtype: int64
